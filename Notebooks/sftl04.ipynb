# %% [markdown]
# Spaceflight data.
# Some questions to ask (<em>Emphasised</em> text indicates as yet unanswered questions):
# <ul>
#     <li>Who's been blasted into space the most times?</li>
#     <li>Who's been to the most different orbits?</li>
#     <li>Which spacecraft has been blasted into space the most times? And how many have been used more than once?</li>
#     <li>Who's spent the most time in space?</li>
#     <li>Which re-usable spacecraft has been used the most frequently?</li>
#     <li>What is the largest number of people to have been on the same spacecraft/mission at the same time? <em>(and when was this?)</em></li>
#     <li><em>What is the largest number of free-flying missions to be in orbit at the same time? (and when was this?)</em></li>
# </ul>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Read in data file

# %%
el = pd.read_csv("data/sftl-full.txt", sep="\t", header=0, parse_dates=[0], dtype={'eventType': 'category'})
el.head()
# Out:
#         date          subject eventType            object
# 0 1960-07-29     Mercury_No.4  SUPPORTS   Mercury-Atlas_1
# 1 1960-07-29  Mercury-Atlas_1   DEPARTS             Earth
# 2 1960-07-29  Mercury-Atlas_1   ARRIVES       Sub_Orbital
# 3 1960-07-29  Mercury-Atlas_1      ENDS               NaN
# 4 1960-08-19    Vostok_1K_KS2  SUPPORTS  Korabl-Sputnik_2

# %% [markdown]
# Some explanation of the data.</br>
# The events describe changes to the state of three and a bit different types of object. The three main types are Mission, Orbit and Component. A mission is a slightly abstract concept that groups together the components for a particular purpose. All the components of a mission are physically connected and share a set of orbital ephemeris. An orbit is a rough grouping of different orbits. E.g. LEO for all low-Earth-orbits. Components are further sub-types into travellers and spacecraft. Travellers are people and animals that have been sent into space. Spacecraft are the ships that carried them. The eventType indicates the type of objects in question as follows:
# <ul>
#     <li>ARRIVES, DEPARTS and ENDS: The subject of the event is a mission, the object is an orbit.</li>
#     <li>JOINS: The subject is a traveller and the object is a mission.</li>
#     <li>SUPPORTS: The subject is a spacecraft and the object is a mission.</li>
# </ul>
# Note that missions can exist without any craft assigned to them. This is typical for missions to space stations whereby the spacecraft becomes part of the space station mission but it's original mission continues until such time as the spacecraft un-docks and returns to Earth.</br>
# Timestamps are only accurate to the nearest day but the order that the events occur is cronologically correct (sort of) and therefore shouldn't be ignored.</br>
# I can't remember what BREAK events are for. I think it might be to separate groups of events that happen on the same day.

# %% [markdown]
# Check the number of different types of events

# %%
el.eventType.unique()
# Out:
# [SUPPORTS, DEPARTS, ARRIVES, ENDS, JOINS, BREAK]
# Categories (6, object): [SUPPORTS, DEPARTS, ARRIVES, ENDS, JOINS, BREAK]

# %% [markdown]
# Pull out all of the unique components and set up a table to track their state.

# %%
componentevents = el[(el['eventType']=="SUPPORTS")|(el['eventType']=="JOINS")]
components = componentevents.subject.unique()
c = pd.DataFrame(index=components)
c["mission"] = None
c["currentstate"] = None
c
# Out:
#                        mission currentstate
# Mercury_No.4              None         None
# Vostok_1K_KS2             None         None
# Belka_and_Strelka         None         None
# Vostok_1K_KS3             None         None
# Pchyolka_and_Mushka       None         None
# ...                        ...          ...
# David_Saint-Jacques       None         None
# Anne_McClain              None         None
# Crew Dragon 2 01          None         None
# Soyuz_MS-12_Spacecraft    None         None
# Christina_Koch            None         None
#
# [918 rows x 2 columns]

# %% [markdown]
# Do the same for missions.

# %%
missionevents = el[(el['eventType']=="DEPARTS")|(el['eventType']=="ARRIVES")]
m = pd.DataFrame(index = missionevents.subject.unique())
m["orbit"]=None
m["currentstate"]=None
m["currentcraft"]=0
m["maxcraft"]=0
m["currenttravellers"]=0
m["maxtravellers"]=0
m
# Out:
#                       orbit currentstate  currentcraft  maxcraft  \
# Mercury-Atlas_1        None         None             0         0
# Korabl-Sputnik_2       None         None             0         0
# Korabl-Sputnik_3       None         None             0         0
# Mercury-Redstone_1A    None         None             0         0
# Unamed_Vostok_Flight1  None         None             0         0
# ...                     ...          ...           ...       ...
# Soyuz_MS-11            None         None             0         0
# New_Shepard#10         None         None             0         0
# Crew_Dragon_Demo-1     None         None             0         0
# Soyuz_MS-12            None         None             0         0
# New_Shepard#11         None         None             0         0
#
#                        currenttravellers  maxtravellers
# Mercury-Atlas_1                        0              0
# Korabl-Sputnik_2                       0              0
# Korabl-Sputnik_3                       0              0
# Mercury-Redstone_1A                    0              0
# Unamed_Vostok_Flight1                  0              0
# ...                                  ...            ...
# Soyuz_MS-11                            0              0
# New_Shepard#10                         0              0
# Crew_Dragon_Demo-1                     0              0
# Soyuz_MS-12                            0              0
# New_Shepard#11                         0              0
#
# [424 rows x 6 columns]

# %% [markdown]
# Create initial states for all missions. This is because most missions start out by having components assigned to them. They don't usually get their own events till later.

# %%
ms = []
for index, mission in m.iterrows():
    msr = {"mission": index, "orbit": None, "startdate": pd.Timestamp.min, "enddate": pd.Timestamp.max}
    m.at[index, "currentstate"] = len(ms)
    ms.append(msr)
m
# Out:
#                       orbit currentstate  currentcraft  maxcraft  \
# Mercury-Atlas_1        None            0             0         0
# Korabl-Sputnik_2       None            1             0         0
# Korabl-Sputnik_3       None            2             0         0
# Mercury-Redstone_1A    None            3             0         0
# Unamed_Vostok_Flight1  None            4             0         0
# ...                     ...          ...           ...       ...
# Soyuz_MS-11            None          419             0         0
# New_Shepard#10         None          420             0         0
# Crew_Dragon_Demo-1     None          421             0         0
# Soyuz_MS-12            None          422             0         0
# New_Shepard#11         None          423             0         0
#
#                        currenttravellers  maxtravellers
# Mercury-Atlas_1                        0              0
# Korabl-Sputnik_2                       0              0
# Korabl-Sputnik_3                       0              0
# Mercury-Redstone_1A                    0              0
# Unamed_Vostok_Flight1                  0              0
# ...                                  ...            ...
# Soyuz_MS-11                            0              0
# New_Shepard#10                         0              0
# Crew_Dragon_Demo-1                     0              0
# Soyuz_MS-12                            0              0
# New_Shepard#11                         0              0
#
# [424 rows x 6 columns]

# %% [markdown]
# Track the history of missions and components. This needs to be done at the same time to keep track of relationships between the two. Essentially it's converting a list of events into a list (two lists) of states.

# %%
cs = []
for index, row in el.iterrows():
    csr = {}
    msr = {}
    laststateindex = None
    if row["eventType"] == "SUPPORTS" or row["eventType"] == "JOINS":
        mission = row["object"]
        # Increment new mission craft / traveller count
        if row["eventType"] == "SUPPORTS":
            m.at[mission, "currentcraft"] += 1
            if m.at[mission, "currentcraft"] > m.at[mission, "maxcraft"]:
                m.at[mission, "maxcraft"] = m.at[mission, "currentcraft"]
        else:
            m.at[mission, "currenttravellers"] += 1
            if m.at[mission, "currenttravellers"] > m.at[mission, "maxtravellers"]:
                m.at[mission, "maxtravellers"] = m.at[mission, "currenttravellers"]
        component = row["subject"]
        # Figure out the date of the last event that changed the state of this component
        laststateindex = c.at[component, "currentstate"]
        csr["pred"] = laststateindex
        # Update the end date of the previous state
        if not(laststateindex is None):
            try:
                cs[laststateindex]["enddate"] = row["date"]
                cs[laststateindex]["succ"] = len(cs)
                # Log the state of the mission we are leaving
                # Look up the mission recorded in the previous state record for this component
                prevmission = cs[laststateindex]["mission"]
                # Look up the current state of this mission
                prevmissionstate = m.at[prevmission, "currentstate"]
                # Update the previous component state record to document the state of the mission when this component left it.
                cs[laststateindex]["endmissionstate"] = prevmissionstate
                # Decrement previous mission craft / traveller count
                if row["eventType"] == "SUPPORTS":
                    m.at[prevmission, "currentcraft"] -= 1
                else:
                    m.at[prevmission, "currenttravellers"] -= 1
            except IndexError:
                print("Index error on component state array access.")
                print("Event: " + str(row))
                print("Length of component state array: " + str(len(cs)))
                print("laststateindex: " + str(laststateindex))
                print("Component record: " + str(c.loc[component]))
        # Create a record for the new state of this component
        csr["startdate"] = row["date"]
        csr["enddate"] = pd.Timestamp.max
        csr["component"] = component
        csr["mission"] = mission
        csr["startmissionstate"] = m.at[mission,"currentstate"]
        cs.append(csr)
        if len(cs) > 0:
            c.at[component, "currentstate"] = len(cs) - 1
        else:
            c.at[component, "currentstate"] = None
    elif row["eventType"] == "ARRIVES" or row["eventType"] == "DEPARTS" or row["eventType"] == "ENDS":
        mission = row["subject"]
        if row["eventType"] == "ARRIVES":
            orbit = row["object"]
        else:
            orbit = str(row["object"]) + "-Tr-"
        # Figure out the date of the last event that changed the state of this mission
        laststateindex = m.at[mission, "currentstate"]
        msr["pred"] = laststateindex
        # Update the previous state
        if not(laststateindex is None):
            try:
                ms[laststateindex]["enddate"] = row["date"]
                if row["eventType"] == "ARRIVES" or row["eventType"] == "DEPARTS":
                    ms[laststateindex]["succ"] = len(ms)
                else:
                    ms[laststateindex]["succ"] = None
                # For departure events, check that the previous state's orbit matches that described in the event
                if row["eventType"] == "DEPARTS":
                    if ms[laststateindex]["orbit"] != row["object"]:
                        # If not, see if it's set at all.
                        if ms[laststateindex]["orbit"] is None:
                            # If not set, use the departure event to update it. Otherwise report a warning.
                            ms[laststateindex]["orbit"] = row["object"]
                        else:
                            print("WARNING: Mission "
                                  + mission
                                  + " departing "
                                  + row["object"]
                                  + " but previously assigned "
                                  + ms[laststateindex]["orbit"])
                # For arrival events, update the "orbit" field of the previous state to capture the destination
                elif row["eventType"] == "ARRIVES":
                    ms[laststateindex]["orbit"] = str(ms[laststateindex]["orbit"]) + str(row["object"])
            except IndexError:
                print("Index error on mission state array access.")
                print("Event: " + str(row))
                print("Length of mission state array: " + str(len(ms)))
                print("laststateindex: " + str(laststateindex))
                print("Mission record: " + str(m.loc[mission]))
        if row["eventType"] == "ARRIVES" or row["eventType"] == "DEPARTS": 
            # Create a record for the new state of this mission
            msr["startdate"] = row["date"]
            msr["enddate"] = pd.Timestamp.max
            msr["mission"] = mission
            msr["orbit"] = orbit
            ms.append(msr)
            if len(ms) > 0:
                m.at[mission, "currentstate"] = len(ms) - 1
            else:
                m.at[mission, "currentstate"] = None

# %%
msdf = pd.DataFrame(ms)
msdf
# Out:
#                     mission                 orbit                  startdate  \
# 0           Mercury-Atlas_1                 Earth 1677-09-21 00:12:43.145225
# 1          Korabl-Sputnik_2                 Earth 1677-09-21 00:12:43.145225
# 2          Korabl-Sputnik_3                 Earth 1677-09-21 00:12:43.145225
# 3       Mercury-Redstone_1A                 Earth 1677-09-21 00:12:43.145225
# 4     Unamed_Vostok_Flight1                 Earth 1677-09-21 00:12:43.145225
# ...                     ...                   ...                        ...
# 2117            Soyuz_MS-12                   LEO 2019-03-14 00:00:00.000000
# 2118         New_Shepard#11  Earth-Tr-Sub_Orbital 2019-05-02 00:00:00.000000
# 2119         New_Shepard#11           Sub_Orbital 2019-05-02 00:00:00.000000
# 2120         New_Shepard#11  Sub_Orbital-Tr-Earth 2019-05-02 00:00:00.000000
# 2121         New_Shepard#11                 Earth 2019-05-02 00:00:00.000000
#
#                            enddate    succ    pred
# 0    1960-07-29 00:00:00.000000000   424.0     NaN
# 1    1960-08-19 00:00:00.000000000   426.0     NaN
# 2    1960-12-01 00:00:00.000000000   430.0     NaN
# 3    1960-12-19 00:00:00.000000000   434.0     NaN
# 4    1960-12-22 00:00:00.000000000   438.0     NaN
# ...                            ...     ...     ...
# 2117 2262-04-11 23:47:16.854775807     NaN  2116.0
# 2118 2019-05-02 00:00:00.000000000  2119.0   423.0
# 2119 2019-05-02 00:00:00.000000000  2120.0  2118.0
# 2120 2019-05-02 00:00:00.000000000  2121.0  2119.0
# 2121 2262-04-11 23:47:16.854775807     NaN  2120.0
#
# [2122 rows x 6 columns]

# %%
csdf = pd.DataFrame(cs)
csdf
# Out:
#         pred  startdate                       enddate               component  \
# 0        NaN 1960-07-29 2262-04-11 23:47:16.854775807            Mercury_No.4
# 1        NaN 1960-08-19 2262-04-11 23:47:16.854775807           Vostok_1K_KS2
# 2        NaN 1960-08-19 2262-04-11 23:47:16.854775807       Belka_and_Strelka
# 3        NaN 1960-12-01 2262-04-11 23:47:16.854775807           Vostok_1K_KS3
# 4        NaN 1960-12-01 2262-04-11 23:47:16.854775807     Pchyolka_and_Mushka
# ...      ...        ...                           ...                     ...
# 3499  3495.0 2019-03-14 2262-04-11 23:47:16.854775807  Soyuz_MS-12_Spacecraft
# 3500  3496.0 2019-03-14 2262-04-11 23:47:16.854775807              Nick_Hague
# 3501  3497.0 2019-03-14 2262-04-11 23:47:16.854775807          Christina_Koch
# 3502  3498.0 2019-03-14 2262-04-11 23:47:16.854775807        Aleksey_Ovchinin
# 3503  3491.0 2019-05-02 2262-04-11 23:47:16.854775807           New_Shepard_3
#
#                           mission  startmissionstate  succ  endmissionstate
# 0                 Mercury-Atlas_1                  0   NaN              NaN
# 1                Korabl-Sputnik_2                  1   NaN              NaN
# 2                Korabl-Sputnik_2                  1   NaN              NaN
# 3                Korabl-Sputnik_3                  2   NaN              NaN
# 4                Korabl-Sputnik_3                  2   NaN              NaN
# ...                           ...                ...   ...              ...
# 3499  International_Space_Station               1589   NaN              NaN
# 3500  International_Space_Station               1589   NaN              NaN
# 3501  International_Space_Station               1589   NaN              NaN
# 3502  International_Space_Station               1589   NaN              NaN
# 3503               New_Shepard#11                423   NaN              NaN
#
# [3504 rows x 8 columns]

# %% [markdown]
# Next, loop through the component state records and create a link table to capture all of the states of a component. Note that some components have no final mission state, this is beacuse they remain part of the mission until it's end. E.g. I guess in theory CSM Endeavour is still part of Apollo 15 to this day.

# %%
import numpy as np
csms = []
for csindex, csr in csdf.iterrows():
    # Find all mission states associated with this component state.
    FirstMissionState = csr["startmissionstate"]
    LastMissionState = csr["endmissionstate"]
    mission = csr["mission"]
    msSubSet = msdf[(msdf.mission == mission) & (msdf.index >= FirstMissionState)]
    if not(np.isnan(LastMissionState)):
        msSubSet = msSubSet[(msSubSet.index <= LastMissionState)]
    for msindex, msr in msSubSet.iterrows():
        csms.append((msindex, csindex))
            
csmsindex = index = pd.MultiIndex.from_tuples(csms, names=['MissionState', 'ComponentState'])
csmsdf = pd.DataFrame(index=csmsindex)
csmsdf
# Out:
# Empty DataFrame
# Columns: []
# Index: [(0, 0), (424, 0), (425, 0), (1, 1), (426, 1), (427, 1), (428, 1), (429, 1), (1, 2), (426, 2), (427, 2), (428, 2), (429, 2), (2, 3), (430, 3), (431, 3), (432, 3), (433, 3), (2, 4), (430, 4), (431, 4), (432, 4), (433, 4), (3, 5), (434, 5), (435, 5), (436, 5), (437, 5), (4, 6), (438, 6), (439, 6), (440, 6), (441, 6), (4, 7), (438, 7), (439, 7), (440, 7), (441, 7), (5, 8), (442, 8), (443, 8), (444, 8), (445, 8), (5, 9), (442, 9), (443, 9), (444, 9), (445, 9), (6, 10), (446, 10), (447, 10), (448, 10), (449, 10), (7, 11), (450, 11), (451, 11), (452, 11), (453, 11), (7, 12), (450, 12), (451, 12), (452, 12), (453, 12), (8, 13), (454, 13), (455, 13), (456, 13), (457, 13), (8, 14), (454, 14), (455, 14), (456, 14), (457, 14), (9, 15), (458, 15), (459, 15), (460, 15), (461, 15), (9, 16), (458, 16), (459, 16), (460, 16), (461, 16), (10, 17), (462, 17), (463, 17), (464, 17), (465, 17), (11, 18), (466, 18), (467, 18), (468, 18), (469, 18), (11, 19), (466, 19), (467, 19), (468, 19), (469, 19), (12, 20), (470, 20), ...]
#
# [10556 rows x 0 columns]

# %%
csmsdf.loc[1,1]
# Out:
# Series([], Name: (1, 1), dtype: float64)

# %% [markdown]
# Join the component and mission states together into a combined set. If a component state is part of a mission that goes through various state changes the component state is repeated for each mission state. E.g. the complete Apollo 15 mission(s).

# %%
x = csmsdf.join(msdf[["orbit", "mission", "startdate", "enddate"]], on="MissionState")
x = x.join(csdf[["component", "startdate", "enddate"]], on="ComponentState", lsuffix="_mission", rsuffix="_component")
x[(x['mission']=="Apollo_15")|(x['mission']=="Apollo_15#Lunar_surface")]
# Out:
#                                                     orbit  \
# MissionState ComponentState
# 89           231                                    Earth
# 798          231                             Earth-Tr-LEO
# 799          231                                      LEO
# 800          231                       LEO-Tr-Lunar_Orbit
# 801          231                              Lunar_Orbit
# 808          231                     Lunar_Orbit-Tr-Earth
# 809          231                                    Earth
# 89           232                                    Earth
# 798          232                             Earth-Tr-LEO
# 799          232                                      LEO
# 800          232                       LEO-Tr-Lunar_Orbit
# 801          232                              Lunar_Orbit
# 89           233                                    Earth
# 798          233                             Earth-Tr-LEO
# 799          233                                      LEO
# 800          233                       LEO-Tr-Lunar_Orbit
# 801          233                              Lunar_Orbit
# 89           234                                    Earth
# 798          234                             Earth-Tr-LEO
# 799          234                                      LEO
# 800          234                       LEO-Tr-Lunar_Orbit
# 801          234                              Lunar_Orbit
# 89           235                                    Earth
# 798          235                             Earth-Tr-LEO
# 799          235                                      LEO
# 800          235                       LEO-Tr-Lunar_Orbit
# 801          235                              Lunar_Orbit
# 808          235                     Lunar_Orbit-Tr-Earth
# 809          235                                    Earth
# 797          236                              Lunar_Orbit
# 802          236             Lunar_Orbit-Tr-Lunar_Surface
# 803          236                            Lunar_Surface
# 804          236             Lunar_Surface-Tr-Lunar_Orbit
# 805          236                              Lunar_Orbit
# 797          237                              Lunar_Orbit
# 802          237             Lunar_Orbit-Tr-Lunar_Surface
# 803          237                            Lunar_Surface
# 804          237             Lunar_Surface-Tr-Lunar_Orbit
# 805          237                              Lunar_Orbit
# 797          238                              Lunar_Orbit
# 802          238             Lunar_Orbit-Tr-Lunar_Surface
# 803          238                            Lunar_Surface
# 804          238             Lunar_Surface-Tr-Lunar_Orbit
# 805          238                              Lunar_Orbit
# 801          239                              Lunar_Orbit
#              240                              Lunar_Orbit
# 808          240                     Lunar_Orbit-Tr-Earth
# 809          240                                    Earth
# 801          241                              Lunar_Orbit
# 808          241                     Lunar_Orbit-Tr-Earth
# 809          241                                    Earth
# 805          242                              Lunar_Orbit
# 806          242             Lunar_Orbit-Tr-Lunar_Surface
# 807          242                            Lunar_Surface
#
#                                              mission  \
# MissionState ComponentState
# 89           231                           Apollo_15
# 798          231                           Apollo_15
# 799          231                           Apollo_15
# 800          231                           Apollo_15
# 801          231                           Apollo_15
# 808          231                           Apollo_15
# 809          231                           Apollo_15
# 89           232                           Apollo_15
# 798          232                           Apollo_15
# 799          232                           Apollo_15
# 800          232                           Apollo_15
# 801          232                           Apollo_15
# 89           233                           Apollo_15
# 798          233                           Apollo_15
# 799          233                           Apollo_15
# 800          233                           Apollo_15
# 801          233                           Apollo_15
# 89           234                           Apollo_15
# 798          234                           Apollo_15
# 799          234                           Apollo_15
# 800          234                           Apollo_15
# 801          234                           Apollo_15
# 89           235                           Apollo_15
# 798          235                           Apollo_15
# 799          235                           Apollo_15
# 800          235                           Apollo_15
# 801          235                           Apollo_15
# 808          235                           Apollo_15
# 809          235                           Apollo_15
# 797          236             Apollo_15#Lunar_surface
# 802          236             Apollo_15#Lunar_surface
# 803          236             Apollo_15#Lunar_surface
# 804          236             Apollo_15#Lunar_surface
# 805          236             Apollo_15#Lunar_surface
# 797          237             Apollo_15#Lunar_surface
# 802          237             Apollo_15#Lunar_surface
# 803          237             Apollo_15#Lunar_surface
# 804          237             Apollo_15#Lunar_surface
# 805          237             Apollo_15#Lunar_surface
# 797          238             Apollo_15#Lunar_surface
# 802          238             Apollo_15#Lunar_surface
# 803          238             Apollo_15#Lunar_surface
# 804          238             Apollo_15#Lunar_surface
# 805          238             Apollo_15#Lunar_surface
# 801          239                           Apollo_15
#              240                           Apollo_15
# 808          240                           Apollo_15
# 809          240                           Apollo_15
# 801          241                           Apollo_15
# 808          241                           Apollo_15
# 809          241                           Apollo_15
# 805          242             Apollo_15#Lunar_surface
# 806          242             Apollo_15#Lunar_surface
# 807          242             Apollo_15#Lunar_surface
#
#                                      startdate_mission enddate_mission  \
# MissionState ComponentState
# 89           231            1677-09-21 00:12:43.145225      1971-07-26
# 798          231            1971-07-26 00:00:00.000000      1971-07-26
# 799          231            1971-07-26 00:00:00.000000      1971-07-26
# 800          231            1971-07-26 00:00:00.000000      1971-07-29
# 801          231            1971-07-29 00:00:00.000000      1971-08-04
# 808          231            1971-08-04 00:00:00.000000      1971-08-07
# 809          231            1971-08-07 00:00:00.000000      1971-08-07
# 89           232            1677-09-21 00:12:43.145225      1971-07-26
# 798          232            1971-07-26 00:00:00.000000      1971-07-26
# 799          232            1971-07-26 00:00:00.000000      1971-07-26
# 800          232            1971-07-26 00:00:00.000000      1971-07-29
# 801          232            1971-07-29 00:00:00.000000      1971-08-04
# 89           233            1677-09-21 00:12:43.145225      1971-07-26
# 798          233            1971-07-26 00:00:00.000000      1971-07-26
# 799          233            1971-07-26 00:00:00.000000      1971-07-26
# 800          233            1971-07-26 00:00:00.000000      1971-07-29
# 801          233            1971-07-29 00:00:00.000000      1971-08-04
# 89           234            1677-09-21 00:12:43.145225      1971-07-26
# 798          234            1971-07-26 00:00:00.000000      1971-07-26
# 799          234            1971-07-26 00:00:00.000000      1971-07-26
# 800          234            1971-07-26 00:00:00.000000      1971-07-29
# 801          234            1971-07-29 00:00:00.000000      1971-08-04
# 89           235            1677-09-21 00:12:43.145225      1971-07-26
# 798          235            1971-07-26 00:00:00.000000      1971-07-26
# 799          235            1971-07-26 00:00:00.000000      1971-07-26
# 800          235            1971-07-26 00:00:00.000000      1971-07-29
# 801          235            1971-07-29 00:00:00.000000      1971-08-04
# 808          235            1971-08-04 00:00:00.000000      1971-08-07
# 809          235            1971-08-07 00:00:00.000000      1971-08-07
# 797          236            1971-07-26 00:00:00.000000      1971-07-30
# 802          236            1971-07-30 00:00:00.000000      1971-07-30
# 803          236            1971-07-30 00:00:00.000000      1971-08-02
# 804          236            1971-08-02 00:00:00.000000      1971-08-02
# 805          236            1971-08-02 00:00:00.000000      1971-08-04
# 797          237            1971-07-26 00:00:00.000000      1971-07-30
# 802          237            1971-07-30 00:00:00.000000      1971-07-30
# 803          237            1971-07-30 00:00:00.000000      1971-08-02
# 804          237            1971-08-02 00:00:00.000000      1971-08-02
# 805          237            1971-08-02 00:00:00.000000      1971-08-04
# 797          238            1971-07-26 00:00:00.000000      1971-07-30
# 802          238            1971-07-30 00:00:00.000000      1971-07-30
# 803          238            1971-07-30 00:00:00.000000      1971-08-02
# 804          238            1971-08-02 00:00:00.000000      1971-08-02
# 805          238            1971-08-02 00:00:00.000000      1971-08-04
# 801          239            1971-07-29 00:00:00.000000      1971-08-04
#              240            1971-07-29 00:00:00.000000      1971-08-04
# 808          240            1971-08-04 00:00:00.000000      1971-08-07
# 809          240            1971-08-07 00:00:00.000000      1971-08-07
# 801          241            1971-07-29 00:00:00.000000      1971-08-04
# 808          241            1971-08-04 00:00:00.000000      1971-08-07
# 809          241            1971-08-07 00:00:00.000000      1971-08-07
# 805          242            1971-08-02 00:00:00.000000      1971-08-04
# 806          242            1971-08-04 00:00:00.000000      1971-08-04
# 807          242            1971-08-04 00:00:00.000000      1971-08-04
#
#                                     component startdate_component  \
# MissionState ComponentState
# 89           231                CSM_Endeavour          1971-07-26
# 798          231                CSM_Endeavour          1971-07-26
# 799          231                CSM_Endeavour          1971-07-26
# 800          231                CSM_Endeavour          1971-07-26
# 801          231                CSM_Endeavour          1971-07-26
# 808          231                CSM_Endeavour          1971-07-26
# 809          231                CSM_Endeavour          1971-07-26
# 89           232                    LM_Falcon          1971-07-26
# 798          232                    LM_Falcon          1971-07-26
# 799          232                    LM_Falcon          1971-07-26
# 800          232                    LM_Falcon          1971-07-26
# 801          232                    LM_Falcon          1971-07-26
# 89           233               James_B._Irwin          1971-07-26
# 798          233               James_B._Irwin          1971-07-26
# 799          233               James_B._Irwin          1971-07-26
# 800          233               James_B._Irwin          1971-07-26
# 801          233               James_B._Irwin          1971-07-26
# 89           234               David_R._Scott          1971-07-26
# 798          234               David_R._Scott          1971-07-26
# 799          234               David_R._Scott          1971-07-26
# 800          234               David_R._Scott          1971-07-26
# 801          234               David_R._Scott          1971-07-26
# 89           235             Alfred_M._Worden          1971-07-26
# 798          235             Alfred_M._Worden          1971-07-26
# 799          235             Alfred_M._Worden          1971-07-26
# 800          235             Alfred_M._Worden          1971-07-26
# 801          235             Alfred_M._Worden          1971-07-26
# 808          235             Alfred_M._Worden          1971-07-26
# 809          235             Alfred_M._Worden          1971-07-26
# 797          236                    LM_Falcon          1971-07-30
# 802          236                    LM_Falcon          1971-07-30
# 803          236                    LM_Falcon          1971-07-30
# 804          236                    LM_Falcon          1971-07-30
# 805          236                    LM_Falcon          1971-07-30
# 797          237               James_B._Irwin          1971-07-30
# 802          237               James_B._Irwin          1971-07-30
# 803          237               James_B._Irwin          1971-07-30
# 804          237               James_B._Irwin          1971-07-30
# 805          237               James_B._Irwin          1971-07-30
# 797          238               David_R._Scott          1971-07-30
# 802          238               David_R._Scott          1971-07-30
# 803          238               David_R._Scott          1971-07-30
# 804          238               David_R._Scott          1971-07-30
# 805          238               David_R._Scott          1971-07-30
# 801          239                    LM_Falcon          1971-08-02
#              240               James_B._Irwin          1971-08-02
# 808          240               James_B._Irwin          1971-08-02
# 809          240               James_B._Irwin          1971-08-02
# 801          241               David_R._Scott          1971-08-02
# 808          241               David_R._Scott          1971-08-02
# 809          241               David_R._Scott          1971-08-02
# 805          242                    LM_Falcon          1971-08-03
# 806          242                    LM_Falcon          1971-08-03
# 807          242                    LM_Falcon          1971-08-03
#
#                                         enddate_component
# MissionState ComponentState
# 89           231            2262-04-11 23:47:16.854775807
# 798          231            2262-04-11 23:47:16.854775807
# 799          231            2262-04-11 23:47:16.854775807
# 800          231            2262-04-11 23:47:16.854775807
# 801          231            2262-04-11 23:47:16.854775807
# 808          231            2262-04-11 23:47:16.854775807
# 809          231            2262-04-11 23:47:16.854775807
# 89           232            1971-07-30 00:00:00.000000000
# 798          232            1971-07-30 00:00:00.000000000
# 799          232            1971-07-30 00:00:00.000000000
# 800          232            1971-07-30 00:00:00.000000000
# 801          232            1971-07-30 00:00:00.000000000
# 89           233            1971-07-30 00:00:00.000000000
# 798          233            1971-07-30 00:00:00.000000000
# 799          233            1971-07-30 00:00:00.000000000
# 800          233            1971-07-30 00:00:00.000000000
# 801          233            1971-07-30 00:00:00.000000000
# 89           234            1971-07-30 00:00:00.000000000
# 798          234            1971-07-30 00:00:00.000000000
# 799          234            1971-07-30 00:00:00.000000000
# 800          234            1971-07-30 00:00:00.000000000
# 801          234            1971-07-30 00:00:00.000000000
# 89           235            2262-04-11 23:47:16.854775807
# 798          235            2262-04-11 23:47:16.854775807
# 799          235            2262-04-11 23:47:16.854775807
# 800          235            2262-04-11 23:47:16.854775807
# 801          235            2262-04-11 23:47:16.854775807
# 808          235            2262-04-11 23:47:16.854775807
# 809          235            2262-04-11 23:47:16.854775807
# 797          236            1971-08-02 00:00:00.000000000
# 802          236            1971-08-02 00:00:00.000000000
# 803          236            1971-08-02 00:00:00.000000000
# 804          236            1971-08-02 00:00:00.000000000
# 805          236            1971-08-02 00:00:00.000000000
# 797          237            1971-08-02 00:00:00.000000000
# 802          237            1971-08-02 00:00:00.000000000
# 803          237            1971-08-02 00:00:00.000000000
# 804          237            1971-08-02 00:00:00.000000000
# 805          237            1971-08-02 00:00:00.000000000
# 797          238            1971-08-02 00:00:00.000000000
# 802          238            1971-08-02 00:00:00.000000000
# 803          238            1971-08-02 00:00:00.000000000
# 804          238            1971-08-02 00:00:00.000000000
# 805          238            1971-08-02 00:00:00.000000000
# 801          239            1971-08-03 00:00:00.000000000
#              240            2262-04-11 23:47:16.854775807
# 808          240            2262-04-11 23:47:16.854775807
# 809          240            2262-04-11 23:47:16.854775807
# 801          241            2262-04-11 23:47:16.854775807
# 808          241            2262-04-11 23:47:16.854775807
# 809          241            2262-04-11 23:47:16.854775807
# 805          242            2262-04-11 23:47:16.854775807
# 806          242            2262-04-11 23:47:16.854775807
# 807          242            2262-04-11 23:47:16.854775807

# %% [markdown]
# Another example: all states for Soyuz_T-15's spacecraft:

# %%
x[(x.component == "Soyuz_T-15_Spacecraft")]
# Out:
#                                     orbit     mission  \
# MissionState ComponentState
# 187          837                    Earth  Soyuz_T-15
# 1194         837             Earth-Tr-LEO  Soyuz_T-15
# 1195         837                      LEO  Soyuz_T-15
# 1193         840                      LEO         Mir
# 1195         843                      LEO  Soyuz_T-15
# 1054         846                      LEO    Salyut_7
# 1195         849                      LEO  Soyuz_T-15
# 1193         852                      LEO         Mir
# 1195         855                      LEO  Soyuz_T-15
# 1196         855             LEO-Tr-Earth  Soyuz_T-15
# 1197         855                    Earth  Soyuz_T-15
#
#                                      startdate_mission  \
# MissionState ComponentState
# 187          837            1677-09-21 00:12:43.145225
# 1194         837            1986-03-13 00:00:00.000000
# 1195         837            1986-03-13 00:00:00.000000
# 1193         840            1986-02-20 00:00:00.000000
# 1195         843            1986-03-13 00:00:00.000000
# 1054         846            1982-04-19 00:00:00.000000
# 1195         849            1986-03-13 00:00:00.000000
# 1193         852            1986-02-20 00:00:00.000000
# 1195         855            1986-03-13 00:00:00.000000
# 1196         855            1986-07-16 00:00:00.000000
# 1197         855            1986-07-16 00:00:00.000000
#
#                                           enddate_mission  \
# MissionState ComponentState
# 187          837            1986-03-13 00:00:00.000000000
# 1194         837            1986-03-13 00:00:00.000000000
# 1195         837            1986-07-16 00:00:00.000000000
# 1193         840            2001-03-23 00:00:00.000000000
# 1195         843            1986-07-16 00:00:00.000000000
# 1054         846            1991-02-07 00:00:00.000000000
# 1195         849            1986-07-16 00:00:00.000000000
# 1193         852            2001-03-23 00:00:00.000000000
# 1195         855            1986-07-16 00:00:00.000000000
# 1196         855            1986-07-16 00:00:00.000000000
# 1197         855            2262-04-11 23:47:16.854775807
#
#                                          component startdate_component  \
# MissionState ComponentState
# 187          837             Soyuz_T-15_Spacecraft          1986-03-13
# 1194         837             Soyuz_T-15_Spacecraft          1986-03-13
# 1195         837             Soyuz_T-15_Spacecraft          1986-03-13
# 1193         840             Soyuz_T-15_Spacecraft          1986-03-15
# 1195         843             Soyuz_T-15_Spacecraft          1986-05-05
# 1054         846             Soyuz_T-15_Spacecraft          1986-05-06
# 1195         849             Soyuz_T-15_Spacecraft          1986-06-25
# 1193         852             Soyuz_T-15_Spacecraft          1986-06-25
# 1195         855             Soyuz_T-15_Spacecraft          1986-07-16
# 1196         855             Soyuz_T-15_Spacecraft          1986-07-16
# 1197         855             Soyuz_T-15_Spacecraft          1986-07-16
#
#                                         enddate_component
# MissionState ComponentState
# 187          837            1986-03-15 00:00:00.000000000
# 1194         837            1986-03-15 00:00:00.000000000
# 1195         837            1986-03-15 00:00:00.000000000
# 1193         840            1986-05-05 00:00:00.000000000
# 1195         843            1986-05-06 00:00:00.000000000
# 1054         846            1986-06-25 00:00:00.000000000
# 1195         849            1986-06-25 00:00:00.000000000
# 1193         852            1986-07-16 00:00:00.000000000
# 1195         855            2262-04-11 23:47:16.854775807
# 1196         855            2262-04-11 23:47:16.854775807
# 1197         855            2262-04-11 23:47:16.854775807

# %% [markdown]
# Next we need to work out the date range for each of the mission+component states. Each will have a start date drawn from the mission state and a second from the component (i.e. when the component became part of the mission). Need to pick the latest start and earliest finish.<br>
# Also, we can use the start and end dates to calculate a duration.

# %%
def duration(row):
    # Duration is meaningless if the state isn't bounded.
    if row.enddate == pd.Timestamp.max or row.startdate == pd.Timestamp.min:
        return pd.NaT
    else:
        return row.enddate - row.startdate
    
x["startdate"] = x.apply(lambda row: max(row.startdate_mission, row.startdate_component), axis=1)
x["enddate"] = x.apply(lambda row: min(row.enddate_mission, row.enddate_component), axis=1)
x["duration"] = x.apply(lambda row: duration(row), axis=1)
x[(x.component == "LM_Falcon")]
# Out:
#                                                     orbit  \
# MissionState ComponentState
# 89           232                                    Earth
# 798          232                             Earth-Tr-LEO
# 799          232                                      LEO
# 800          232                       LEO-Tr-Lunar_Orbit
# 801          232                              Lunar_Orbit
# 797          236                              Lunar_Orbit
# 802          236             Lunar_Orbit-Tr-Lunar_Surface
# 803          236                            Lunar_Surface
# 804          236             Lunar_Surface-Tr-Lunar_Orbit
# 805          236                              Lunar_Orbit
# 801          239                              Lunar_Orbit
# 805          242                              Lunar_Orbit
# 806          242             Lunar_Orbit-Tr-Lunar_Surface
# 807          242                            Lunar_Surface
#
#                                              mission  \
# MissionState ComponentState
# 89           232                           Apollo_15
# 798          232                           Apollo_15
# 799          232                           Apollo_15
# 800          232                           Apollo_15
# 801          232                           Apollo_15
# 797          236             Apollo_15#Lunar_surface
# 802          236             Apollo_15#Lunar_surface
# 803          236             Apollo_15#Lunar_surface
# 804          236             Apollo_15#Lunar_surface
# 805          236             Apollo_15#Lunar_surface
# 801          239                           Apollo_15
# 805          242             Apollo_15#Lunar_surface
# 806          242             Apollo_15#Lunar_surface
# 807          242             Apollo_15#Lunar_surface
#
#                                      startdate_mission enddate_mission  \
# MissionState ComponentState
# 89           232            1677-09-21 00:12:43.145225      1971-07-26
# 798          232            1971-07-26 00:00:00.000000      1971-07-26
# 799          232            1971-07-26 00:00:00.000000      1971-07-26
# 800          232            1971-07-26 00:00:00.000000      1971-07-29
# 801          232            1971-07-29 00:00:00.000000      1971-08-04
# 797          236            1971-07-26 00:00:00.000000      1971-07-30
# 802          236            1971-07-30 00:00:00.000000      1971-07-30
# 803          236            1971-07-30 00:00:00.000000      1971-08-02
# 804          236            1971-08-02 00:00:00.000000      1971-08-02
# 805          236            1971-08-02 00:00:00.000000      1971-08-04
# 801          239            1971-07-29 00:00:00.000000      1971-08-04
# 805          242            1971-08-02 00:00:00.000000      1971-08-04
# 806          242            1971-08-04 00:00:00.000000      1971-08-04
# 807          242            1971-08-04 00:00:00.000000      1971-08-04
#
#                              component startdate_component  \
# MissionState ComponentState
# 89           232             LM_Falcon          1971-07-26
# 798          232             LM_Falcon          1971-07-26
# 799          232             LM_Falcon          1971-07-26
# 800          232             LM_Falcon          1971-07-26
# 801          232             LM_Falcon          1971-07-26
# 797          236             LM_Falcon          1971-07-30
# 802          236             LM_Falcon          1971-07-30
# 803          236             LM_Falcon          1971-07-30
# 804          236             LM_Falcon          1971-07-30
# 805          236             LM_Falcon          1971-07-30
# 801          239             LM_Falcon          1971-08-02
# 805          242             LM_Falcon          1971-08-03
# 806          242             LM_Falcon          1971-08-03
# 807          242             LM_Falcon          1971-08-03
#
#                                         enddate_component  startdate  \
# MissionState ComponentState
# 89           232            1971-07-30 00:00:00.000000000 1971-07-26
# 798          232            1971-07-30 00:00:00.000000000 1971-07-26
# 799          232            1971-07-30 00:00:00.000000000 1971-07-26
# 800          232            1971-07-30 00:00:00.000000000 1971-07-26
# 801          232            1971-07-30 00:00:00.000000000 1971-07-29
# 797          236            1971-08-02 00:00:00.000000000 1971-07-30
# 802          236            1971-08-02 00:00:00.000000000 1971-07-30
# 803          236            1971-08-02 00:00:00.000000000 1971-07-30
# 804          236            1971-08-02 00:00:00.000000000 1971-08-02
# 805          236            1971-08-02 00:00:00.000000000 1971-08-02
# 801          239            1971-08-03 00:00:00.000000000 1971-08-02
# 805          242            2262-04-11 23:47:16.854775807 1971-08-03
# 806          242            2262-04-11 23:47:16.854775807 1971-08-04
# 807          242            2262-04-11 23:47:16.854775807 1971-08-04
#
#                                enddate duration
# MissionState ComponentState
# 89           232            1971-07-26   0 days
# 798          232            1971-07-26   0 days
# 799          232            1971-07-26   0 days
# 800          232            1971-07-29   3 days
# 801          232            1971-07-30   1 days
# 797          236            1971-07-30   0 days
# 802          236            1971-07-30   0 days
# 803          236            1971-08-02   3 days
# 804          236            1971-08-02   0 days
# 805          236            1971-08-02   0 days
# 801          239            1971-08-03   1 days
# 805          242            1971-08-04   1 days
# 806          242            1971-08-04   0 days
# 807          242            1971-08-04   0 days

# %% [markdown]
# Lets do stuff with state durations, hence we can ignore the dates.

# %%
y = x[["orbit","mission", "component", "duration"]]
y
# Out:
#                                             orbit           mission  \
# MissionState ComponentState
# 0            0                              Earth   Mercury-Atlas_1
# 424          0               Earth-Tr-Sub_Orbital   Mercury-Atlas_1
# 425          0                        Sub_Orbital   Mercury-Atlas_1
# 1            1                              Earth  Korabl-Sputnik_2
# 426          1                       Earth-Tr-LEO  Korabl-Sputnik_2
# ...                                           ...               ...
# 423          3503                           Earth    New_Shepard#11
# 2118         3503            Earth-Tr-Sub_Orbital    New_Shepard#11
# 2119         3503                     Sub_Orbital    New_Shepard#11
# 2120         3503            Sub_Orbital-Tr-Earth    New_Shepard#11
# 2121         3503                           Earth    New_Shepard#11
#
#                                  component duration
# MissionState ComponentState
# 0            0                Mercury_No.4   0 days
# 424          0                Mercury_No.4   0 days
# 425          0                Mercury_No.4   0 days
# 1            1               Vostok_1K_KS2   0 days
# 426          1               Vostok_1K_KS2   0 days
# ...                                    ...      ...
# 423          3503            New_Shepard_3   0 days
# 2118         3503            New_Shepard_3   0 days
# 2119         3503            New_Shepard_3   0 days
# 2120         3503            New_Shepard_3   0 days
# 2121         3503            New_Shepard_3      NaT
#
# [10556 rows x 4 columns]

# %%
y.groupby(["orbit","component"]).sum()
# Out:
#                                                                                    mission  \
# orbit                component
# Earth                7K-L1 K146                                                 Kosmos_146
#                      7K-L1 K154                                       Kosmos_154Kosmos_154
#                      7K-L1 Z4                                                 Zond_4Zond_4
#                      Abdul_Ahad_Mohmand                               Soyuz_TM-6Soyuz_TM-5
#                      Aidyn_Aimbetov                             Soyuz_TMA-18MSoyuz_TMA-16M
# ...                                                                                    ...
# Sub_Orbital-Tr-Earth SpaceShipOne_X0     SpaceShipOne_flight_15PSpaceShipOne_flight_16P...
#                      Vasily_Lazarev                                              Soyuz_18a
#                      Virgil_Grissom                                     Mercury-Redstone_4
#                      Vostok_1K_UN                                    Unamed_Vostok_Flight1
#                      X-15 No.3                                X-15_Flight_90X-15_Flight_91
#
#                                         duration
# orbit                component
# Earth                7K-L1 K146           0 days
#                      7K-L1 K154           0 days
#                      7K-L1 Z4             0 days
#                      Abdul_Ahad_Mohmand   0 days
#                      Aidyn_Aimbetov       0 days
# ...                                          ...
# Sub_Orbital-Tr-Earth SpaceShipOne_X0      0 days
#                      Vasily_Lazarev       0 days
#                      Virgil_Grissom       0 days
#                      Vostok_1K_UN         0 days
#                      X-15 No.3            0 days
#
# [3852 rows x 2 columns]

# %% [markdown]
# Next work out the type of each component (craft or traveller).

# %%
componentTypes = el[(el['eventType']=="SUPPORTS")|(el['eventType']=="JOINS")][["subject","eventType"]].groupby(["subject","eventType"], observed=True).count()
componentTypes
# Out:
# Empty DataFrame
# Columns: []
# Index: [(7K-L1 K146, SUPPORTS), (7K-L1 K154, SUPPORTS), (7K-L1 Z4, SUPPORTS), (Abdul_Ahad_Mohmand, JOINS), (Aidyn_Aimbetov, JOINS), (Akihiko_Hoshide, JOINS), (Alan_B._Shepard, JOINS), (Alan_Bean, JOINS), (Alan_G._Poindexter, JOINS), (Alan_L._Bean, JOINS), (Alan_Shepard, JOINS), (Albert_Sacco, JOINS), (Aleksandr_Aleksandrovich_Skvortsov, JOINS), (Aleksandr_Ivanchenkov, JOINS), (Aleksandr_Kaleri, JOINS), (Aleksandr_Lazutkin, JOINS), (Aleksandr_Nikolayevich_Balandin, JOINS), (Aleksandr_Panayotov_Aleksandrov, JOINS), (Aleksandr_Pavlovich_Aleksandrov, JOINS), (Aleksandr_Poleshchuk, JOINS), (Aleksandr_Samokutyayev, JOINS), (Aleksandr_Serebrov, JOINS), (Aleksandr_Skvortsov_(cosmonaut), JOINS), (Aleksandr_Viktorenko, JOINS), (Aleksei_Gubarev, JOINS), (Aleksei_Yeliseyev, JOINS), (Aleksey_Gubarev, JOINS), (Aleksey_Ovchinin, JOINS), (Alexander_Alexandrovich_Volkov_(cosmonaut), JOINS), (Alexander_Gerst, JOINS), (Alexander_Laveykin, JOINS), (Alexander_Misurkin, JOINS), (Alexander_Viktorenko, JOINS), (Alexei_Leonov, JOINS), (Alfred_M._Worden, JOINS), (Anatoli_Artsebarsky, JOINS), (Anatoli_Brergovoy, JOINS), (Anatoli_Ivanishin, JOINS), (Anatoli_Levchenko, JOINS), (Anatoly_Filipchenko, JOINS), (Anatoly_Solovyev, JOINS), (Andr%C3%A9_Kuipers, JOINS), (Andreas_Mogensen, JOINS), (Andrei_Borisenko, JOINS), (Andrew_J._Feustel, JOINS), (Andrew_M._Allen, JOINS), (Andrew_S._W._Thomas, JOINS), (Andriyan_Nikolayev, JOINS), (Andy_Thomas, JOINS), (Anna_Lee_Fisher, JOINS), (Anne_McClain, JOINS), (Anousheh_Ansari, JOINS), (Anthony_W._England, JOINS), (Anton_Shkaplerov, JOINS), (Apollo_CSM-009, SUPPORTS), (Apollo_CSM-011, SUPPORTS), (Apollo_CSM-017, SUPPORTS), (Apollo_CSM-020, SUPPORTS), (Apollo_CSM-101, SUPPORTS), (Apollo_CSM-103, SUPPORTS), (Apollo_CSM-111, SUPPORTS), (Apollo_CSM-116, SUPPORTS), (Apollo_CSM-117, SUPPORTS), (Apollo_CSM-118, SUPPORTS), (Apollo_LM-1, SUPPORTS), (Arnaldo_Tamayo-Mendez, JOINS), (Aurora_7, SUPPORTS), (Barbara_R._Morgan, JOINS), (Barry_E._Wilmore, JOINS), (Belka_and_Strelka, JOINS), (Benjamin_A._Drew, JOINS), (Bernard_A._Harris, JOINS), (Bertalan_Farkas, JOINS), (Bigelow Expandable Activity Module, SUPPORTS), (Bjarni_Tryggvason, JOINS), (Bonnie_J._Dunbar, JOINS), (Boris_Morukov, JOINS), (Boris_Volynov, JOINS), (Boris_Yegorov, JOINS), (Brent_W._Jett, JOINS), (Brewster_H._Shaw, JOINS), (Brian_Binnie, JOINS), (Brian_Duffy_(astronaut), JOINS), (Bruce_E._Melnick, JOINS), (Bruce_McCandless_II, JOINS), (Bryan_D._O%27Connor, JOINS), (Buzz_Aldrin, JOINS), (Byron_K._Lichtenberg, JOINS), (C._Gordon_Fullerton, JOINS), (C._Michael_Foale, JOINS), (CSM_America, SUPPORTS), (CSM_Casper, SUPPORTS), (CSM_Charlie_Brown, SUPPORTS), (CSM_Columbia, SUPPORTS), (CSM_Endeavour, SUPPORTS), (CSM_Gumdrop, SUPPORTS), (CSM_Kitty_Hawk, SUPPORTS), (CSM_Odessey, SUPPORTS), (CSM_Yankee_Clipper, SUPPORTS), (Carl_E._Walz, JOINS), ...]
#
# [918 rows x 0 columns]

# %%
mapDict = {"SUPPORTS":"craft","JOINS":"traveller"}
componentTypes = pd.DataFrame(componentTypes.reset_index(level=["eventType"])["eventType"].map(mapDict))
componentTypes
# Out:
#                     eventType
# subject
# 7K-L1 K146              craft
# 7K-L1 K154              craft
# 7K-L1 Z4                craft
# Abdul_Ahad_Mohmand  traveller
# Aidyn_Aimbetov      traveller
# ...                       ...
# Zarya                   craft
# Zhai_Zhigang        traveller
# Zhang_Xiaoguang     traveller
# Zvezda                  craft
# Zvyozdochka         traveller
#
# [918 rows x 1 columns]

# %%
z = y.join(componentTypes, on="component")

# %% [markdown]
# Now finally do something interesting. Find out the total number of days each traveller has spent away from Earth.

# %%
TravellerTotals = z[(z["eventType"]=="traveller")&(z["orbit"]!="Earth")].groupby(["component", "eventType"]).sum()
TravellerTotals[["mission","duration"]].sort_values(by="duration",ascending=False).head(20)
# Out:
#                                                                                                 mission  \
# component                                  eventType
# Gennady_Padalka                            traveller  Soyuz_TM-28Soyuz_TM-28MirSoyuz_TM-28Soyuz_TM-2...
# Yuri_Malenchenko                           traveller  Soyuz_TM-19Soyuz_TM-19MirSoyuz_TM-19Soyuz_TM-1...
# Sergei_Krikalev                            traveller  Soyuz_TM-7Soyuz_TM-7MirSoyuz_TM-7Soyuz_TM-7Soy...
# Aleksandr_Kaleri                           traveller  Soyuz_TM-14Soyuz_TM-14MirSoyuz_TM-14Soyuz_TM-1...
# Sergei_Avdeyev                             traveller  Soyuz_TM-15Soyuz_TM-15MirSoyuz_TM-15Soyuz_TM-1...
# Fyodor_Yurchikhin                          traveller  STS-112STS-112International_Space_StationSTS-1...
# Anatoly_Solovyev                           traveller  Soyuz_TM-5Soyuz_TM-5MirSoyuz_TM-4Soyuz_TM-4Soy...
# Pavel_Vinogradov                           traveller  Soyuz_TM-26Soyuz_TM-26MirSoyuz_TM-26Soyuz_TM-2...
# Viktor_Afanasyev_(cosmonaut)               traveller  Soyuz_TM-11Soyuz_TM-11MirSoyuz_TM-11Soyuz_TM-1...
# Musa_Manarov                               traveller  Soyuz_TM-4Soyuz_TM-4MirSoyuz_TM-6Soyuz_TM-6Soy...
# Oleg_Kononenko                             traveller  Soyuz_TMA-12Soyuz_TMA-12International_Space_St...
# Anton_Shkaplerov                           traveller  Soyuz_TMA-22Soyuz_TMA-22International_Space_St...
# Mikhail_Tyurin                             traveller  STS-105STS-105International_Space_StationSTS-1...
# Oleg_Kotov                                 traveller  Soyuz_TMA-10Soyuz_TMA-10International_Space_St...
# Scott_Kelly_(astronaut)                    traveller  STS-103STS-103STS-103STS-118STS-118Internation...
# Mikhail_Korniyenko                         traveller  Soyuz_TMA-18Soyuz_TMA-18International_Space_St...
# Nikolai_Budarin                            traveller  STS-71STS-71MirSoyuz_TM-21Soyuz_TM-21Soyuz_TM-...
# Valeri_Polyokov                            traveller    Soyuz_TM-18Soyuz_TM-18MirSoyuz_TM-20Soyuz_TM-20
# Yuri_Romanenko                             traveller  Soyuz_26Soyuz_26Salyut_6Soyuz_27Soyuz_27Soyuz_...
# Alexander_Alexandrovich_Volkov_(cosmonaut) traveller  Soyuz_T-14Soyuz_T-14Salyut_7Soyuz_T-14Soyuz_T-...
#
#                                                      duration
# component                                  eventType
# Gennady_Padalka                            traveller 878 days
# Yuri_Malenchenko                           traveller 825 days
# Sergei_Krikalev                            traveller 803 days
# Aleksandr_Kaleri                           traveller 769 days
# Sergei_Avdeyev                             traveller 744 days
# Fyodor_Yurchikhin                          traveller 675 days
# Anatoly_Solovyev                           traveller 628 days
# Pavel_Vinogradov                           traveller 547 days
# Viktor_Afanasyev_(cosmonaut)               traveller 546 days
# Musa_Manarov                               traveller 541 days
# Oleg_Kononenko                             traveller 534 days
# Anton_Shkaplerov                           traveller 533 days
# Mikhail_Tyurin                             traveller 532 days
# Oleg_Kotov                                 traveller 528 days
# Scott_Kelly_(astronaut)                    traveller 522 days
# Mikhail_Korniyenko                         traveller 517 days
# Nikolai_Budarin                            traveller 446 days
# Valeri_Polyokov                            traveller 438 days
# Yuri_Romanenko                             traveller 429 days
# Alexander_Alexandrovich_Volkov_(cosmonaut) traveller 392 days

# %% [markdown]
# Time spent either orbiting on on the surface of the moon.

# %%
TravellerTotalsByOrbit = z[(z["eventType"]=="traveller")&((z["orbit"]=="Lunar_Orbit")|(z["orbit"]=="Lunar_Surface"))].groupby(["component", "eventType"]).sum()
TravellerTotalsByOrbit.sort_values(by="duration",ascending=False)
# Out:
#                                                                                    orbit  \
# component                   eventType
# Eugene_Cernan               traveller  Lunar_OrbitLunar_OrbitLunar_OrbitLunar_OrbitLu...
# John_Young_(astronaut)      traveller  Lunar_OrbitLunar_OrbitLunar_OrbitLunar_Surface...
# Alfred_M._Worden            traveller                                        Lunar_Orbit
# Ronald_Evans_(astronaut)    traveller                                        Lunar_Orbit
# David_R._Scott              traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Thomas_K._Mattingly         traveller                                        Lunar_Orbit
# James_B._Irwin              traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Harrison_H._Schmitt         traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Charles_M._Duke             traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Michael_Collins_(astronaut) traveller                                        Lunar_Orbit
# Richard_F._Gordon_Jr.       traveller                                        Lunar_Orbit
# Pete_Conrad                 traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Neil_Armstrong              traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Alan_B._Shepard             traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Alan_Bean                   traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Thomas_P._Stafford          traveller                  Lunar_OrbitLunar_OrbitLunar_Orbit
# Edgar_D._Mitchell           traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Buzz_Aldrin                 traveller  Lunar_OrbitLunar_OrbitLunar_SurfaceLunar_Orbit...
# Stuart_A._Roosa             traveller                                        Lunar_Orbit
# Jim_Lovell                  traveller                                        Lunar_Orbit
# Frank_Borman                traveller                                        Lunar_Orbit
# William_Anders              traveller                                        Lunar_Orbit
#
#                                                                                  mission  \
# component                   eventType
# Eugene_Cernan               traveller  Apollo_10Apollo_10#LM–CSM_dockingApollo_10Apol...
# John_Young_(astronaut)      traveller  Apollo_10Apollo_16Apollo_16#Lunar_surfaceApoll...
# Alfred_M._Worden            traveller                                          Apollo_15
# Ronald_Evans_(astronaut)    traveller                                          Apollo_17
# David_R._Scott              traveller  Apollo_15Apollo_15#Lunar_surfaceApollo_15#Luna...
# Thomas_K._Mattingly         traveller                                          Apollo_16
# James_B._Irwin              traveller  Apollo_15Apollo_15#Lunar_surfaceApollo_15#Luna...
# Harrison_H._Schmitt         traveller  Apollo_17Apollo_17#Moon_landingApollo_17#Moon_...
# Charles_M._Duke             traveller  Apollo_16Apollo_16#Lunar_surfaceApollo_16#Luna...
# Michael_Collins_(astronaut) traveller                                          Apollo_11
# Richard_F._Gordon_Jr.       traveller                                          Apollo_12
# Pete_Conrad                 traveller  Apollo_12Apollo_12#Moon_landingApollo_12#Moon_...
# Neil_Armstrong              traveller  Apollo_11Apollo_11#LandingApollo_11#LandingApo...
# Alan_B._Shepard             traveller  Apollo_14Apollo_14#Lunar_descentApollo_14#Luna...
# Alan_Bean                   traveller  Apollo_12Apollo_12#Moon_landingApollo_12#Moon_...
# Thomas_P._Stafford          traveller         Apollo_10Apollo_10#LM–CSM_dockingApollo_10
# Edgar_D._Mitchell           traveller  Apollo_14Apollo_14#Lunar_descentApollo_14#Luna...
# Buzz_Aldrin                 traveller  Apollo_11Apollo_11#LandingApollo_11#LandingApo...
# Stuart_A._Roosa             traveller                                          Apollo_14
# Jim_Lovell                  traveller                                           Apollo_8
# Frank_Borman                traveller                                           Apollo_8
# William_Anders              traveller                                           Apollo_8
#
#                                       duration
# component                   eventType
# Eugene_Cernan               traveller   8 days
# John_Young_(astronaut)      traveller   8 days
# Alfred_M._Worden            traveller   6 days
# Ronald_Evans_(astronaut)    traveller   6 days
# David_R._Scott              traveller   6 days
# Thomas_K._Mattingly         traveller   6 days
# James_B._Irwin              traveller   6 days
# Harrison_H._Schmitt         traveller   5 days
# Charles_M._Duke             traveller   5 days
# Michael_Collins_(astronaut) traveller   3 days
# Richard_F._Gordon_Jr.       traveller   3 days
# Pete_Conrad                 traveller   3 days
# Neil_Armstrong              traveller   3 days
# Alan_B._Shepard             traveller   3 days
# Alan_Bean                   traveller   3 days
# Thomas_P._Stafford          traveller   3 days
# Edgar_D._Mitchell           traveller   3 days
# Buzz_Aldrin                 traveller   3 days
# Stuart_A._Roosa             traveller   3 days
# Jim_Lovell                  traveller   1 days
# Frank_Borman                traveller   1 days
# William_Anders              traveller   1 days

# %% [markdown]
# Lets try some counting of traveller launches. Assume that each occurrence of a transfer orbit starting with "EARTH" is a launch.

# %%
TravellerLaunchCounts = z[(z["eventType"]=="traveller")&((z["orbit"]=="Earth-Tr-LEO")|(z["orbit"]=="Earth-Tr-Sub_Orbital"))].groupby(["component", "eventType"]).count()
TravellerLaunchCounts.sort_values(by="duration",ascending=False).head(20)
# Out:
#                                   orbit  mission  duration
# component              eventType
# Franklin_R._Chang-Diaz traveller      7        7         7
# Jerry_L._Ross          traveller      7        7         7
# Curtis_L._Brown        traveller      6        6         6
# Sergei_Krikalev        traveller      6        6         6
# F._Story_Musgrave      traveller      6        6         6
# Yuri_Malenchenko       traveller      6        6         6
# C._Michael_Foale       traveller      6        6         6
# Steven_A._Hawley       traveller      5        5         5
# James_D._Halsell       traveller      5        5         5
# Kenneth_D._Bowersox    traveller      5        5         5
# Kenneth_D._Cockrell    traveller      5        5         5
# Kent_V._Rominger       traveller      5        5         5
# Anatoly_Solovyev       traveller      5        5         5
# Bonnie_J._Dunbar       traveller      5        5         5
# Scott_E._Parazynski    traveller      5        5         5
# Gennady_Padalka        traveller      5        5         5
# Vladimir_Dzhanibekov   traveller      5        5         5
# Fyodor_Yurchikhin      traveller      5        5         5
# Shannon_W._Lucid       traveller      5        5         5
# James_D._Wetherbee     traveller      5        5         5

# %% [markdown]
# Lets try the same for craft.

# %%
CraftLaunchCounts = z[(z["eventType"]=="craft")&((z["orbit"]=="Earth-Tr-LEO")|(z["orbit"]=="Earth-Tr-Sub_Orbital"))].groupby(["component", "eventType"]).count()
CraftLaunchCounts.sort_values(by="duration",ascending=False).head(20)
# Out:
#                                     orbit  mission  duration
# component                eventType
# Space_Shuttle_Discovery  craft         39       39        39
# Space_Shuttle_Atlantis   craft         33       33        33
# Space_Shuttle_Columbia   craft         28       28        28
# Space_Shuttle_Endeavour  craft         25       25        25
# Space_Shuttle_Challenger craft         10       10        10
# SPACEHAB SM              craft          7        7         7
# SPACEHAB LDM             craft          7        7         7
# New_Shepard_2            craft          5        5         5
# New_Shepard_3            craft          5        5         5
# SpaceShipOne_X0          craft          3        3         3
# Mercury_No.8             craft          2        2         2
# VA 102L                  craft          2        2         2
# SPACEHAB LSM             craft          2        2         2
# X-15 No.3                craft          2        2         2
# VA 102P                  craft          2        2         2
# Soyuz_TM-24_Spacecraft   craft          1        1         1
# Soyuz_TM-27_Spacecraft   craft          1        1         1
# Soyuz_TM-26_Spacecraft   craft          1        1         1
# Soyuz_TM-25_Spacecraft   craft          1        1         1
# Soyuz_TM-23_Spacecraft   craft          1        1         1

# %% [markdown]
# Find all the re-usable spacecraft and break out the orbital and sub-orbital launches. Again assume a "launch" is a transfer from EARTH to either LEO or Sub_Orbital.

# %%
craftLauchesByOrbit = z.loc[
    (z["eventType"]=="craft")&((z["orbit"]=="Earth-Tr-LEO")|(z["orbit"]=="Earth-Tr-Sub_Orbital"))
    ,["component", "orbit", "mission"]]\
    .groupby(["component", "orbit"])\
    .count()\
    .unstack()
totalLaunches = z.loc[
    (z["eventType"]=="craft")&((z["orbit"]=="Earth-Tr-LEO")|(z["orbit"]=="Earth-Tr-Sub_Orbital"))
    ,["component", "orbit", "mission"]]\
    .groupby(["component"])\
    .count()["orbit"]
craftLauchesByOrbit["totLaunch"] = totalLaunches
craftLauchesByOrbit.sort_values(by="totLaunch",ascending=False)\
    .head(20)
# Out:
#                               mission                      totLaunch
# orbit                    Earth-Tr-LEO Earth-Tr-Sub_Orbital
# component
# Space_Shuttle_Discovery          39.0                  NaN        39
# Space_Shuttle_Atlantis           33.0                  NaN        33
# Space_Shuttle_Columbia           28.0                  NaN        28
# Space_Shuttle_Endeavour          25.0                  NaN        25
# Space_Shuttle_Challenger          9.0                  1.0        10
# SPACEHAB SM                       7.0                  NaN         7
# SPACEHAB LDM                      7.0                  NaN         7
# New_Shepard_2                     NaN                  5.0         5
# New_Shepard_3                     NaN                  5.0         5
# SpaceShipOne_X0                   NaN                  3.0         3
# Mercury_No.8                      2.0                  NaN         2
# VA 102L                           2.0                  NaN         2
# SPACEHAB LSM                      2.0                  NaN         2
# X-15 No.3                         NaN                  2.0         2
# VA 102P                           2.0                  NaN         2
# Soyuz_TM-24_Spacecraft            1.0                  NaN         1
# Soyuz_TM-27_Spacecraft            1.0                  NaN         1
# Soyuz_TM-26_Spacecraft            1.0                  NaN         1
# Soyuz_TM-25_Spacecraft            1.0                  NaN         1
# Soyuz_TM-23_Spacecraft            1.0                  NaN         1

# %% [markdown]
# Lets use the above approach to get more detail on space traveller total duration.

# %%
import datetime
travellerDurationByOrbit = z.loc[
    (z["eventType"]=="traveller")
    &(z["duration"] > datetime.timedelta(0))
    ,["component", "orbit", "duration"]]\
    .groupby(["component", "orbit"])\
    .sum()\
    .unstack()
totalTravellerDuration = z.loc[
    (z["eventType"]=="traveller")&(z["orbit"]!="Earth")
    ,["component", "orbit", "duration"]]\
    .groupby(["component"])\
    .sum()["duration"]
travellerDurationByOrbit["totDuration"] = totalTravellerDuration
travellerDurationByOrbit.sort_values(by="totDuration",ascending=False).head(30)
# Out:
#                                             duration           \
# orbit                                          Earth      LEO
# component
# Gennady_Padalka                            5359 days 878 days
# Yuri_Malenchenko                           7196 days 825 days
# Sergei_Krikalev                            5360 days 803 days
# Aleksandr_Kaleri                           6169 days 769 days
# Sergei_Avdeyev                             1844 days 744 days
# Fyodor_Yurchikhin                          4770 days 675 days
# Anatoly_Solovyev                           2916 days 628 days
# Pavel_Vinogradov                           5333 days 547 days
# Viktor_Afanasyev_(cosmonaut)               2645 days 546 days
# Musa_Manarov                                711 days 541 days
# Oleg_Kononenko                             3357 days 534 days
# Anton_Shkaplerov                           1860 days 533 days
# Mikhail_Tyurin                             4128 days 532 days
# Oleg_Kotov                                 2002 days 528 days
# Scott_Kelly_(astronaut)                    5396 days 522 days
# Mikhail_Korniyenko                         1644 days 517 days
# Nikolai_Budarin                            2422 days 446 days
# Valeri_Polyokov                                  NaT 438 days
# Yuri_Romanenko                             3242 days 429 days
# Alexander_Alexandrovich_Volkov_(cosmonaut) 1989 days 392 days
# Yuri_Onufrienko                            1920 days 390 days
# Michael_Fincke                             2217 days 382 days
# Leonid_Kizim                               1678 days 379 days
# Vladimir_Titov                             4904 days 379 days
# Peggy_A._Whitson                           1768 days 377 days
# Yuri_Usachyev                               592 days 376 days
# Aleksandr_Serebrov                         3792 days 373 days
# C._Michael_Foale                           4047 days 372 days
# Oleg_Artemyev                              1287 days 367 days
# Vladimir_Solovyov_(cosmonaut)               527 days 366 days
#
#                                                                \
# orbit                                      LEO-Tr-Lunar_Flyby
# component
# Gennady_Padalka                                           NaT
# Yuri_Malenchenko                                          NaT
# Sergei_Krikalev                                           NaT
# Aleksandr_Kaleri                                          NaT
# Sergei_Avdeyev                                            NaT
# Fyodor_Yurchikhin                                         NaT
# Anatoly_Solovyev                                          NaT
# Pavel_Vinogradov                                          NaT
# Viktor_Afanasyev_(cosmonaut)                              NaT
# Musa_Manarov                                              NaT
# Oleg_Kononenko                                            NaT
# Anton_Shkaplerov                                          NaT
# Mikhail_Tyurin                                            NaT
# Oleg_Kotov                                                NaT
# Scott_Kelly_(astronaut)                                   NaT
# Mikhail_Korniyenko                                        NaT
# Nikolai_Budarin                                           NaT
# Valeri_Polyokov                                           NaT
# Yuri_Romanenko                                            NaT
# Alexander_Alexandrovich_Volkov_(cosmonaut)                NaT
# Yuri_Onufrienko                                           NaT
# Michael_Fincke                                            NaT
# Leonid_Kizim                                              NaT
# Vladimir_Titov                                            NaT
# Peggy_A._Whitson                                          NaT
# Yuri_Usachyev                                             NaT
# Aleksandr_Serebrov                                        NaT
# C._Michael_Foale                                          NaT
# Oleg_Artemyev                                             NaT
# Vladimir_Solovyov_(cosmonaut)                             NaT
#
#                                                                \
# orbit                                      LEO-Tr-Lunar_Orbit
# component
# Gennady_Padalka                                           NaT
# Yuri_Malenchenko                                          NaT
# Sergei_Krikalev                                           NaT
# Aleksandr_Kaleri                                          NaT
# Sergei_Avdeyev                                            NaT
# Fyodor_Yurchikhin                                         NaT
# Anatoly_Solovyev                                          NaT
# Pavel_Vinogradov                                          NaT
# Viktor_Afanasyev_(cosmonaut)                              NaT
# Musa_Manarov                                              NaT
# Oleg_Kononenko                                            NaT
# Anton_Shkaplerov                                          NaT
# Mikhail_Tyurin                                            NaT
# Oleg_Kotov                                                NaT
# Scott_Kelly_(astronaut)                                   NaT
# Mikhail_Korniyenko                                        NaT
# Nikolai_Budarin                                           NaT
# Valeri_Polyokov                                           NaT
# Yuri_Romanenko                                            NaT
# Alexander_Alexandrovich_Volkov_(cosmonaut)                NaT
# Yuri_Onufrienko                                           NaT
# Michael_Fincke                                            NaT
# Leonid_Kizim                                              NaT
# Vladimir_Titov                                            NaT
# Peggy_A._Whitson                                          NaT
# Yuri_Usachyev                                             NaT
# Aleksandr_Serebrov                                        NaT
# C._Michael_Foale                                          NaT
# Oleg_Artemyev                                             NaT
# Vladimir_Solovyov_(cosmonaut)                             NaT
#
#                                                                              \
# orbit                                      Lunar_Flyby-Tr-Earth Lunar_Orbit
# component
# Gennady_Padalka                                             NaT         NaT
# Yuri_Malenchenko                                            NaT         NaT
# Sergei_Krikalev                                             NaT         NaT
# Aleksandr_Kaleri                                            NaT         NaT
# Sergei_Avdeyev                                              NaT         NaT
# Fyodor_Yurchikhin                                           NaT         NaT
# Anatoly_Solovyev                                            NaT         NaT
# Pavel_Vinogradov                                            NaT         NaT
# Viktor_Afanasyev_(cosmonaut)                                NaT         NaT
# Musa_Manarov                                                NaT         NaT
# Oleg_Kononenko                                              NaT         NaT
# Anton_Shkaplerov                                            NaT         NaT
# Mikhail_Tyurin                                              NaT         NaT
# Oleg_Kotov                                                  NaT         NaT
# Scott_Kelly_(astronaut)                                     NaT         NaT
# Mikhail_Korniyenko                                          NaT         NaT
# Nikolai_Budarin                                             NaT         NaT
# Valeri_Polyokov                                             NaT         NaT
# Yuri_Romanenko                                              NaT         NaT
# Alexander_Alexandrovich_Volkov_(cosmonaut)                  NaT         NaT
# Yuri_Onufrienko                                             NaT         NaT
# Michael_Fincke                                              NaT         NaT
# Leonid_Kizim                                                NaT         NaT
# Vladimir_Titov                                              NaT         NaT
# Peggy_A._Whitson                                            NaT         NaT
# Yuri_Usachyev                                               NaT         NaT
# Aleksandr_Serebrov                                          NaT         NaT
# C._Michael_Foale                                            NaT         NaT
# Oleg_Artemyev                                               NaT         NaT
# Vladimir_Solovyov_(cosmonaut)                               NaT         NaT
#
#                                                                  \
# orbit                                      Lunar_Orbit-Tr-Earth
# component
# Gennady_Padalka                                             NaT
# Yuri_Malenchenko                                            NaT
# Sergei_Krikalev                                             NaT
# Aleksandr_Kaleri                                            NaT
# Sergei_Avdeyev                                              NaT
# Fyodor_Yurchikhin                                           NaT
# Anatoly_Solovyev                                            NaT
# Pavel_Vinogradov                                            NaT
# Viktor_Afanasyev_(cosmonaut)                                NaT
# Musa_Manarov                                                NaT
# Oleg_Kononenko                                              NaT
# Anton_Shkaplerov                                            NaT
# Mikhail_Tyurin                                              NaT
# Oleg_Kotov                                                  NaT
# Scott_Kelly_(astronaut)                                     NaT
# Mikhail_Korniyenko                                          NaT
# Nikolai_Budarin                                             NaT
# Valeri_Polyokov                                             NaT
# Yuri_Romanenko                                              NaT
# Alexander_Alexandrovich_Volkov_(cosmonaut)                  NaT
# Yuri_Onufrienko                                             NaT
# Michael_Fincke                                              NaT
# Leonid_Kizim                                                NaT
# Vladimir_Titov                                              NaT
# Peggy_A._Whitson                                            NaT
# Yuri_Usachyev                                               NaT
# Aleksandr_Serebrov                                          NaT
# C._Michael_Foale                                            NaT
# Oleg_Artemyev                                               NaT
# Vladimir_Solovyov_(cosmonaut)                               NaT
#
#                                                                          \
# orbit                                      Lunar_Orbit-Tr-Lunar_Surface
# component
# Gennady_Padalka                                                     NaT
# Yuri_Malenchenko                                                    NaT
# Sergei_Krikalev                                                     NaT
# Aleksandr_Kaleri                                                    NaT
# Sergei_Avdeyev                                                      NaT
# Fyodor_Yurchikhin                                                   NaT
# Anatoly_Solovyev                                                    NaT
# Pavel_Vinogradov                                                    NaT
# Viktor_Afanasyev_(cosmonaut)                                        NaT
# Musa_Manarov                                                        NaT
# Oleg_Kononenko                                                      NaT
# Anton_Shkaplerov                                                    NaT
# Mikhail_Tyurin                                                      NaT
# Oleg_Kotov                                                          NaT
# Scott_Kelly_(astronaut)                                             NaT
# Mikhail_Korniyenko                                                  NaT
# Nikolai_Budarin                                                     NaT
# Valeri_Polyokov                                                     NaT
# Yuri_Romanenko                                                      NaT
# Alexander_Alexandrovich_Volkov_(cosmonaut)                          NaT
# Yuri_Onufrienko                                                     NaT
# Michael_Fincke                                                      NaT
# Leonid_Kizim                                                        NaT
# Vladimir_Titov                                                      NaT
# Peggy_A._Whitson                                                    NaT
# Yuri_Usachyev                                                       NaT
# Aleksandr_Serebrov                                                  NaT
# C._Michael_Foale                                                    NaT
# Oleg_Artemyev                                                       NaT
# Vladimir_Solovyov_(cosmonaut)                                       NaT
#
#                                                           \
# orbit                                      Lunar_Surface
# component
# Gennady_Padalka                                      NaT
# Yuri_Malenchenko                                     NaT
# Sergei_Krikalev                                      NaT
# Aleksandr_Kaleri                                     NaT
# Sergei_Avdeyev                                       NaT
# Fyodor_Yurchikhin                                    NaT
# Anatoly_Solovyev                                     NaT
# Pavel_Vinogradov                                     NaT
# Viktor_Afanasyev_(cosmonaut)                         NaT
# Musa_Manarov                                         NaT
# Oleg_Kononenko                                       NaT
# Anton_Shkaplerov                                     NaT
# Mikhail_Tyurin                                       NaT
# Oleg_Kotov                                           NaT
# Scott_Kelly_(astronaut)                              NaT
# Mikhail_Korniyenko                                   NaT
# Nikolai_Budarin                                      NaT
# Valeri_Polyokov                                      NaT
# Yuri_Romanenko                                       NaT
# Alexander_Alexandrovich_Volkov_(cosmonaut)           NaT
# Yuri_Onufrienko                                      NaT
# Michael_Fincke                                       NaT
# Leonid_Kizim                                         NaT
# Vladimir_Titov                                       NaT
# Peggy_A._Whitson                                     NaT
# Yuri_Usachyev                                        NaT
# Aleksandr_Serebrov                                   NaT
# C._Michael_Foale                                     NaT
# Oleg_Artemyev                                        NaT
# Vladimir_Solovyov_(cosmonaut)                        NaT
#
#                                                                          \
# orbit                                      Lunar_Surface-Tr-Lunar_Orbit
# component
# Gennady_Padalka                                                     NaT
# Yuri_Malenchenko                                                    NaT
# Sergei_Krikalev                                                     NaT
# Aleksandr_Kaleri                                                    NaT
# Sergei_Avdeyev                                                      NaT
# Fyodor_Yurchikhin                                                   NaT
# Anatoly_Solovyev                                                    NaT
# Pavel_Vinogradov                                                    NaT
# Viktor_Afanasyev_(cosmonaut)                                        NaT
# Musa_Manarov                                                        NaT
# Oleg_Kononenko                                                      NaT
# Anton_Shkaplerov                                                    NaT
# Mikhail_Tyurin                                                      NaT
# Oleg_Kotov                                                          NaT
# Scott_Kelly_(astronaut)                                             NaT
# Mikhail_Korniyenko                                                  NaT
# Nikolai_Budarin                                                     NaT
# Valeri_Polyokov                                                     NaT
# Yuri_Romanenko                                                      NaT
# Alexander_Alexandrovich_Volkov_(cosmonaut)                          NaT
# Yuri_Onufrienko                                                     NaT
# Michael_Fincke                                                      NaT
# Leonid_Kizim                                                        NaT
# Vladimir_Titov                                                      NaT
# Peggy_A._Whitson                                                    NaT
# Yuri_Usachyev                                                       NaT
# Aleksandr_Serebrov                                                  NaT
# C._Michael_Foale                                                    NaT
# Oleg_Artemyev                                                       NaT
# Vladimir_Solovyov_(cosmonaut)                                       NaT
#
#                                            totDuration
# orbit
# component
# Gennady_Padalka                               878 days
# Yuri_Malenchenko                              825 days
# Sergei_Krikalev                               803 days
# Aleksandr_Kaleri                              769 days
# Sergei_Avdeyev                                744 days
# Fyodor_Yurchikhin                             675 days
# Anatoly_Solovyev                              628 days
# Pavel_Vinogradov                              547 days
# Viktor_Afanasyev_(cosmonaut)                  546 days
# Musa_Manarov                                  541 days
# Oleg_Kononenko                                534 days
# Anton_Shkaplerov                              533 days
# Mikhail_Tyurin                                532 days
# Oleg_Kotov                                    528 days
# Scott_Kelly_(astronaut)                       522 days
# Mikhail_Korniyenko                            517 days
# Nikolai_Budarin                               446 days
# Valeri_Polyokov                               438 days
# Yuri_Romanenko                                429 days
# Alexander_Alexandrovich_Volkov_(cosmonaut)    392 days
# Yuri_Onufrienko                               390 days
# Michael_Fincke                                382 days
# Leonid_Kizim                                  379 days
# Vladimir_Titov                                379 days
# Peggy_A._Whitson                              377 days
# Yuri_Usachyev                                 376 days
# Aleksandr_Serebrov                            373 days
# C._Michael_Foale                              372 days
# Oleg_Artemyev                                 367 days
# Vladimir_Solovyov_(cosmonaut)                 366 days

# %% [markdown]
# Bit boring as LEO durations totally eclipse all other orbits.

# %% [markdown]
# I'm intersted in which traveller has been to the most different orbits (I have a feeling it's Jim Lovell)...

# %%
travellerOrbits = pd.DataFrame(z[(z["eventType"]=="traveller")].groupby("component").orbit.unique())
travellerOrbits["uniqueOrbitCount"] = travellerOrbits.apply(lambda row: len(row.orbit), axis=1)
travellerOrbits.sort_values(by="uniqueOrbitCount", ascending=False).head(35)
# Out:
#                                                                          orbit  \
# component
# Buzz_Aldrin                  [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Neil_Armstrong               [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Pete_Conrad                  [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Jim_Lovell                   [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# John_Young_(astronaut)       [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Eugene_Cernan                [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Edgar_D._Mitchell            [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Alan_B._Shepard              [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Alan_Bean                    [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Harrison_H._Schmitt          [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# James_B._Irwin               [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# David_R._Scott               [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Charles_M._Duke              [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Frank_Borman                 [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Michael_Collins_(astronaut)  [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Aleksey_Ovchinin             [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, Earth...
# Thomas_K._Mattingly          [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Oleg_Grigoryevich_Makarov    [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, Earth...
# Thomas_P._Stafford           [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Richard_F._Gordon_Jr.        [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# William_Anders               [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Nick_Hague                   [Earth, Earth-Tr-Sub_Orbital, Sub_Orbital, Sub...
# Jack_Swigert                 [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Flyby,...
# Michael_P._Anderson          [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Stuart_A._Roosa              [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Kalpana_Chawla               [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Alfred_M._Worden             [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Rick_Husband                 [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, LEO-T...
# Ronald_E._McNair             [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, Earth...
# Ellison_S._Onizuka           [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Earth, Earth...
# Ronald_Evans_(astronaut)     [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Orbit,...
# Fred_Haise                   [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Lunar_Flyby,...
# Laurel_B._Clark              [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Sub_Orbital,...
# Pchyolka_and_Mushka          [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Sub_Orbital,...
# William_C._McCool            [Earth, Earth-Tr-LEO, LEO, LEO-Tr-Sub_Orbital,...
#
#                              uniqueOrbitCount
# component
# Buzz_Aldrin                                10
# Neil_Armstrong                             10
# Pete_Conrad                                10
# Jim_Lovell                                 10
# John_Young_(astronaut)                     10
# Eugene_Cernan                              10
# Edgar_D._Mitchell                           9
# Alan_B._Shepard                             9
# Alan_Bean                                   9
# Harrison_H._Schmitt                         9
# James_B._Irwin                              9
# David_R._Scott                              9
# Charles_M._Duke                             9
# Frank_Borman                                7
# Michael_Collins_(astronaut)                 7
# Aleksey_Ovchinin                            7
# Thomas_K._Mattingly                         7
# Oleg_Grigoryevich_Makarov                   7
# Thomas_P._Stafford                          7
# Richard_F._Gordon_Jr.                       7
# William_Anders                              6
# Nick_Hague                                  6
# Jack_Swigert                                6
# Michael_P._Anderson                         6
# Stuart_A._Roosa                             6
# Kalpana_Chawla                              6
# Alfred_M._Worden                            6
# Rick_Husband                                6
# Ronald_E._McNair                            6
# Ellison_S._Onizuka                          6
# Ronald_Evans_(astronaut)                    6
# Fred_Haise                                  6
# Laurel_B._Clark                             5
# Pchyolka_and_Mushka                         5
# William_C._McCool                           5

# %% [markdown]
# Hmm, this is mostly just highlighting issues with the data. I wonder if I should ignore transfer "orbits"...

# %% [markdown]
# Checking how many people have actually been to the moon...

# %%
moonMen = z[(z["eventType"]=="traveller")&((z["orbit"]=="Lunar_Orbit")|(z["orbit"]=="Lunar_Flyby"))].groupby("component").orbit.unique()
moonMen
# Out:
# component
# Alan_B._Shepard                             [Lunar_Orbit]
# Alan_Bean                                   [Lunar_Orbit]
# Alfred_M._Worden                            [Lunar_Orbit]
# Buzz_Aldrin                                 [Lunar_Orbit]
# Charles_M._Duke                             [Lunar_Orbit]
# David_R._Scott                              [Lunar_Orbit]
# Edgar_D._Mitchell                           [Lunar_Orbit]
# Eugene_Cernan                               [Lunar_Orbit]
# Frank_Borman                                [Lunar_Orbit]
# Fred_Haise                                  [Lunar_Flyby]
# Harrison_H._Schmitt                         [Lunar_Orbit]
# Jack_Swigert                                [Lunar_Flyby]
# James_B._Irwin                              [Lunar_Orbit]
# Jim_Lovell                     [Lunar_Orbit, Lunar_Flyby]
# John_Young_(astronaut)                      [Lunar_Orbit]
# Michael_Collins_(astronaut)                 [Lunar_Orbit]
# Neil_Armstrong                              [Lunar_Orbit]
# Pete_Conrad                                 [Lunar_Orbit]
# Richard_F._Gordon_Jr.                       [Lunar_Orbit]
# Ronald_Evans_(astronaut)                    [Lunar_Orbit]
# Stuart_A._Roosa                             [Lunar_Orbit]
# Thomas_K._Mattingly                         [Lunar_Orbit]
# Thomas_P._Stafford                          [Lunar_Orbit]
# William_Anders                              [Lunar_Orbit]
# Name: orbit, dtype: object

# %%
len(moonMen)
# Out:
# 24

# %% [markdown]
# There should be 24. And technicaly they were all on a flyby before their orbit insertion burns...
# Ah ha, I have Eugene_A._Cernan AND Eugene_Cernan. Lets find out which is the most common.

# %%
z[(z["component"]=="Eugene_A._Cernan")|(z["component"]=="Eugene_Cernan")].groupby(["component","mission"]).count()
# Out:
#                                         orbit  duration  eventType
# component     mission
# Eugene_Cernan Apollo_10                     8         8          8
#               Apollo_10#LM–CSM_docking      1         1          1
#               Apollo_17                     8         8          8
#               Apollo_17#Moon_landing        5         5          5
#               Gemini_9A                     5         5          5

# %% [markdown]
# Done a search and replace on the original data. Now the above comments don't make any sense...

# %% [markdown]
# Lets have a go at launch frequency. Or maybe launch interval? (Should that be from landing to launch? Or launch to launch?)

# %%
ComponentLaunches = x.loc[((x["orbit"]=="Earth-Tr-LEO")|(z["orbit"]=="Earth-Tr-Sub_Orbital")),["mission","component","startdate"]]
ComponentLaunchIntervals = ComponentLaunches.groupby("component").agg({'mission':'count','startdate': lambda x: x.max() - x.min()})
meanLaunchIntervals = ComponentLaunchIntervals[(ComponentLaunchIntervals["mission"]>1)].apply(lambda row: row["startdate"] / (row["mission"]-1), axis=1)
ComponentLaunchIntervals["meanLaunchIntervals"] = meanLaunchIntervals
ComponentLaunchIntervals[(ComponentLaunchIntervals["mission"]>1)].sort_values(by="meanLaunchIntervals", ascending=True).head(30)
# Out:
#                           mission startdate      meanLaunchIntervals
# component
# X-15 No.3                       2   34 days         34 days 00:00:00
# Joseph_A._Walker                2   34 days         34 days 00:00:00
# SpaceShipOne_X0                 3  105 days         52 days 12:00:00
# New_Shepard_2                   5  317 days         79 days 06:00:00
# Susan_L._Still                  2   88 days         88 days 00:00:00
# Gregory_T._Linteris             2   88 days         88 days 00:00:00
# Roger_K._Crouch                 2   88 days         88 days 00:00:00
# Mike_Melvill                    2  100 days        100 days 00:00:00
# Space_Shuttle_Challenger       10 1061 days        117 days 21:20:00
# New_Shepard_3                   5  506 days        126 days 12:00:00
# Mercury_No.8                    2  141 days        141 days 00:00:00
# Nick_Hague                      2  154 days        154 days 00:00:00
# Paul_S._Lockhart                2  171 days        171 days 00:00:00
# Charles_D._Walker               3  453 days        226 days 12:00:00
# SPACEHAB LSM                    2  241 days        241 days 00:00:00
# SPACEHAB LDM                    7 1453 days        242 days 04:00:00
# Space_Shuttle_Discovery        39 9674 days 254 days 13:53:41.052631
# Space_Shuttle_Endeavour        25 6948 days        289 days 12:00:00
# Space_Shuttle_Atlantis         33 9409 days        294 days 00:45:00
# Space_Shuttle_Columbia         28 7949 days        294 days 09:46:40
# SPACEHAB SM                     7 1956 days        326 days 00:00:00
# Donald_A._Thomas                4 1089 days        363 days 00:00:00
# Michael_T._Good                 2  368 days        368 days 00:00:00
# Ellison_S._Onizuka              2  400 days        400 days 00:00:00
# Aleksei_Yeliseyev               3  828 days        414 days 00:00:00
# Vladimir_Shatalov               3  829 days        414 days 12:00:00
# Stephen_G._Bowen                3  831 days        415 days 12:00:00
# Mario_Runco                     2  416 days        416 days 00:00:00
# VA 102L                         2  418 days        418 days 00:00:00
# VA 102P                         2  418 days        418 days 00:00:00

# %% [markdown]
# So the above is based on launch to launch interval. Quite interesting I guess. I think landing to launch would be much harder.

# %% [markdown]
# Analysing max traveller and craft stats that I added in earlier.

# %%
m.sort_values(by="maxcraft", ascending=False).head(15)
# Out:
#                             orbit currentstate  currentcraft  maxcraft  \
# International_Space_Station  None         1589            18        18
# Mir                          None         1657             6        10
# Salyut_7                     None         1299             2         4
# Salyut_6                     None         1066             2         3
# STS-130                      None         1879             0         3
# STS-88                       None         1593             0         2
# STS-123                      None         1819             0         2
# Skylab                       None          997             1         2
# STS-77                       None         1507             0         2
# Apollo_17                    None          839             1         2
# Apollo_13                    None          751             2         2
# STS-79                       None         1519             0         2
# Apollo_16                    None          826             1         2
# STS-81                       None         1527             0         2
# Kosmos_186                   None          619             1         2
#
#                              currenttravellers  maxtravellers
# International_Space_Station                  6             13
# Mir                                          0             13
# Salyut_7                                     0              6
# Salyut_6                                     0              4
# STS-130                                      5              6
# STS-88                                       1              6
# STS-123                                      4              7
# Skylab                                       0              3
# STS-77                                       2              6
# Apollo_17                                    3              3
# Apollo_13                                    3              3
# STS-79                                       4              6
# Apollo_16                                    1              3
# STS-81                                       2              6
# Kosmos_186                                   0              0

# %% [markdown]
# Which is great, but I'd really like to understand the circumstances of these maximums.
